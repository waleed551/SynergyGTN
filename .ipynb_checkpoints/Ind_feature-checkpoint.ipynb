# %%
import os
import numpy as np
from math import sqrt
from scipy import stats
import torch
from torch_geometric.data import InMemoryDataset
from torch_geometric import data as DATA
from torch_geometric.loader import DataLoader
import os
import pandas as pd
import numpy as np
import json,pickle
from collections import OrderedDict
from rdkit import Chem
from rdkit.Chem import MolFromSmiles
import networkx as nx

import os
import os.path as osp
import re

import torch
from torch_geometric.data import (InMemoryDataset, Data, download_url,
                                  extract_gz)

try:
    from rdkit import Chem
except ImportError:
    Chem = None

# %%
def smiles_features(mol):
    symbols = ['K', 'Y', 'V', 'Sm', 'Dy', 'In', 'Lu', 'Hg', 'Co', 'Mg',    #list of all elements in the dataset
        'Cu', 'Rh', 'Hf', 'O', 'As', 'Ge', 'Au', 'Mo', 'Br', 'Ce', 
        'Zr', 'Ag', 'Ba', 'N', 'Cr', 'Sr', 'Fe', 'Gd', 'I', 'Al', 
        'B', 'Se', 'Pr', 'Te', 'Cd', 'Pd', 'Si', 'Zn', 'Pb', 'Sn', 
        'Cl', 'Mn', 'Cs', 'Na', 'S', 'Ti', 'Ni', 'Ru', 'Ca', 'Nd', 
        'W', 'H', 'Li', 'Sb', 'Bi', 'La', 'Pt', 'Nb', 'P', 'F', 'C',
        'Re','Ta','Ir','Be','Tl']

    hybridizations = [
        Chem.rdchem.HybridizationType.S,
        Chem.rdchem.HybridizationType.SP,
        Chem.rdchem.HybridizationType.SP2,
        Chem.rdchem.HybridizationType.SP3,
        Chem.rdchem.HybridizationType.SP3D,
        Chem.rdchem.HybridizationType.SP3D2,
        'other',
    ]

    stereos = [
        Chem.rdchem.BondStereo.STEREONONE,
        Chem.rdchem.BondStereo.STEREOANY,
        Chem.rdchem.BondStereo.STEREOZ,
        Chem.rdchem.BondStereo.STEREOE,
    ]
    features = []
    xs = []
    for atom in mol.GetAtoms():
        symbol = [0.] * len(symbols)
        symbol[symbols.index(atom.GetSymbol())] = 1.
        #comment degree from 6 to 8
        degree = [0.] * 8
        degree[atom.GetDegree()] = 1.
        formal_charge = atom.GetFormalCharge()
        radical_electrons = atom.GetNumRadicalElectrons()
        hybridization = [0.] * len(hybridizations)
        hybridization[hybridizations.index(
            atom.GetHybridization())] = 1.
        aromaticity = 1. if atom.GetIsAromatic() else 0.
        hydrogens = [0.] * 5
        hydrogens[atom.GetTotalNumHs()] = 1.
        chirality = 1. if atom.HasProp('_ChiralityPossible') else 0.
        chirality_type = [0.] * 2
        if atom.HasProp('_CIPCode'):
            chirality_type[['R', 'S'].index(atom.GetProp('_CIPCode'))] = 1.
    
        x = torch.tensor(symbol + degree + [formal_charge] +
                         [radical_electrons] + hybridization +
                         [aromaticity] + hydrogens + [chirality] +
                         chirality_type)
        xs.append(x)
    
        x = torch.stack(xs, dim=0)

    edge_indices = []
    edge_attrs = []
    for bond in mol.GetBonds():
        edge_indices += [[bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]]
        edge_indices += [[bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]]
    
        bond_type = bond.GetBondType()
        single = 1. if bond_type == Chem.rdchem.BondType.SINGLE else 0.
        double = 1. if bond_type == Chem.rdchem.BondType.DOUBLE else 0.
        triple = 1. if bond_type == Chem.rdchem.BondType.TRIPLE else 0.
        aromatic = 1. if bond_type == Chem.rdchem.BondType.AROMATIC else 0.
        conjugation = 1. if bond.GetIsConjugated() else 0.
        ring = 1. if bond.IsInRing() else 0.
        stereo = [0.] * 4
        stereo[stereos.index(bond.GetStereo())] = 1.
    
        edge_attr = torch.tensor(
            [single, double, triple, aromatic, conjugation, ring] + stereo)
    
        edge_attrs += [edge_attr, edge_attr]
    
    if len(edge_attrs) == 0:
        edge_index = torch.zeros((2, 0), dtype=torch.long)
        edge_attr = torch.zeros((0, 10), dtype=torch.float)
    else:
        edge_index = torch.tensor(edge_indices).t().contiguous()
        edge_attr = torch.stack(edge_attrs, dim=0)
    return x, edge_index, edge_attr

def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception("input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))

def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def smile_to_graph(smile):
    mol = Chem.MolFromSmiles(smile)
    if mol == None:
        return None
    
    c_size = mol.GetNumAtoms()
    features, edge_index, edge_attr = smiles_features(mol)
    # features = []
    # bonds = mol.GetBonds()
    # for atom in mol.GetAtoms():
    #     feature = atom_features(atom)
    #     features.append( feature / sum(feature) )

    # edges = []
    # for bond in mol.GetBonds():
    #     edges.append([bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()])
    # g = nx.Graph(edges).to_directed()
    # edge_index = []
    # for e1, e2 in g.edges:
    #     edge_index.append([e1, e2])
        
    return features, edge_index, edge_attr

# %%
class Molecule_data(InMemoryDataset):
    def __init__(self, root='/tmp', dataset='_drug1',xd=None, xt=None, y=None, xt_featrue=None, transform=None,
                 pre_transform=None,smile_graph=None):

        #root is required for save preprocessed data, default is '/tmp'
        super(Molecule_data, self).__init__(root, transform, pre_transform)
        # benchmark dataset, default = 'davis'
        self.dataset = dataset
        if os.path.isfile(self.processed_paths[0]):
#             print('Pre-processed data found: {}, loading ...'.format(self.processed_paths[0]))
            self.data, self.slices = torch.load(self.processed_paths[0])
        else:
            print('Pre-processed data {} not found, doing pre-processing...'.format(self.processed_paths[0]))
            self.process(xd, xt, xt_featrue, y, smile_graph)
            self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def raw_file_names(self):
        pass
        #return ['some_file_1', 'some_file_2', ...]

    @property
    def processed_file_names(self):
        return [self.dataset + '.pt']

    def download(self):
        # Download to `self.raw_dir`.
        pass

    def _download(self):
        pass

    def _process(self):
        if not os.path.exists(self.processed_dir):
            os.makedirs(self.processed_dir)
            
    def get_cell_feature(self, cellId, cell_features):
        for row in islice(cell_features, 0, None):
            if cellId in row[0]:
                return row[1:]
        return False

    def process(self, xd, xt, xt_featrue,y,smile_graph):
        assert (len(xd) == len(xt) and len(xt) == len(y)), "The three lists must be the same length!"
        data_list = []
        data_len = len(xd)
        for i in range(data_len):
            print('Converting SMILES to graph: {}/{}'.format(i+1, data_len))
            smiles = xd[i]
            target = xt[i]
            labels = y[i]
            # convert SMILES to molecular representation using rdkit
            x, edge_index, edge_attr = smile_graph[smiles]
            # make the graph ready for PyTorch Geometrics GCN algorithms:
            GCNData = Data(x=torch.Tensor(x),
                      edge_index=edge_index,
                      edge_attr=edge_attr,
                      y=torch.FloatTensor([labels]))
        
            cell = self.get_cell_feature(target, xt_featrue)

            if cell == False : 
                print('cell', cell)
                sys.exit()

            new_cell = []
            # print('cell_feature', cell_feature)
            for n in cell:
                new_cell.append(float(n))
            GCNData.cell = torch.FloatTensor([new_cell])
            #GCNData.__setitem__('c_size', torch.LongTensor([c_size]))
            # append graph, label and target sequence to data list
            data_list.append(GCNData)

        if self.pre_filter is not None:
            data_list = [data for data in data_list if self.pre_filter(data)]

        if self.pre_transform is not None:
            data_list = [self.pre_transform(data) for data in data_list]
        print('Graph construction done. Saving to file.')
        data, slices = self.collate(data_list)
#         print(data.shape,slices.shape)
        # save preprocessed data:
        torch.save((data, slices), self.processed_paths[0])

# %%
import csv
from itertools import islice

import pandas as pd
import numpy as np
import os
import json, pickle
from collections import OrderedDict
from rdkit import Chem
import networkx as nx


def creat_data(datafile, cellfile):
    file2 = cellfile
    cell_features = []
    with open(file2) as csvfile:
        csv_reader = csv.reader(csvfile)  # 使用csv.reader读取csvfile中的文件
        for row in csv_reader:
            cell_features.append(row)
    cell_features = np.array(cell_features)
    print('cell_features', cell_features)

    compound_iso_smiles = []
    df = pd.read_csv('data/smiles.csv')
    compound_iso_smiles += list(df['smile'])
    compound_iso_smiles = set(compound_iso_smiles)
    smile_graph = {}
    for smile in compound_iso_smiles:
        g = smile_to_graph(smile)
        smile_graph[smile] = g

    datasets = datafile
    # convert to PyTorch data format
    processed_data_file_train = 'data_perparation/processed/' + datasets + '_train.pt'

    if ((not os.path.isfile(processed_data_file_train))):
        df = pd.read_csv('data/' + datasets + '.csv')
        drug1, drug2, cell, label = list(df['drug1']), list(df['drug2']), list(df['cell']), list(df['label'])
        drug1, drug2, cell, label = np.asarray(drug1), np.asarray(drug2), np.asarray(cell), np.asarray(label)
        # make data PyTorch Geometric ready
        print(len(cell),len(label))
      
        Molecule_data(root='data_perparation', dataset=datafile + '_drug1', xd=drug1, xt=cell, xt_featrue=cell_features, y=label,smile_graph=smile_graph)
        Molecule_data(root='data_perparation', dataset=datafile + '_drug2', xd=drug2, xt=cell, xt_featrue=cell_features, y=label,smile_graph=smile_graph)
       
        print('preparing ', datasets + '_.pt in pytorch format!')
    #
    #     print(processed_data_file_train, ' have been created')
    #
    # else:
    #     print(processed_data_file_train, ' are already created')

if __name__ == "__main__":
    # datafile = 'prostate'
    cellfile = 'data/new_cell_features_954.csv'
    da = ['A375']
    for datafile in da:
        creat_data(datafile, cellfile)
# Out:
# cell_features [['gene_id' 'ENSG00000116237' 'ENSG00000162413' ... 'ENSG00000157617'
#   'ENSG00000160208' 'ENSG00000141959']
#  ['transcript_id' 'ENST00000343813' 'ENST00000377658' ...
#   'ENST00000329623' 'ENST00000340648' 'ENST00000349048']
#  ['A2058' '51.07' '20.76' ... '1.46' '23.67' '78.86']
#  ...
#  ['YKG1_CENTRAL_NERVOUS_SYSTEM' '41.25' '23.28' ... '1.72' '18.24'
#   '71.48']
#  ['ZR751_BREAST' '30.69' '4.72' ... '0.77' '6.8' '36.37']
#  ['ZR7530_BREAST' '25.04' '7.31' ... '5.44' '10.06' '73.45']]
# 425 425
# Pre-processed data data_perparation/processed/A375_drug1.pt not found, doing pre-processing...
# Converting SMILES to graph: 1/425
# Converting SMILES to graph: 2/425
# Converting SMILES to graph: 3/425
# Converting SMILES to graph: 4/425
# Converting SMILES to graph: 5/425
# Converting SMILES to graph: 6/425
# Converting SMILES to graph: 7/425
# Converting SMILES to graph: 8/425
# Converting SMILES to graph: 9/425
# Converting SMILES to graph: 10/425
# Converting SMILES to graph: 11/425
# Converting SMILES to graph: 12/425
# Converting SMILES to graph: 13/425
# Converting SMILES to graph: 14/425
# Converting SMILES to graph: 15/425
# Converting SMILES to graph: 16/425
# Converting SMILES to graph: 17/425
# Converting SMILES to graph: 18/425
# Converting SMILES to graph: 19/425
# Converting SMILES to graph: 20/425
# Converting SMILES to graph: 21/425
# Converting SMILES to graph: 22/425
# Converting SMILES to graph: 23/425
# Converting SMILES to graph: 24/425
# Converting SMILES to graph: 25/425
# Converting SMILES to graph: 26/425
# Converting SMILES to graph: 27/425
# Converting SMILES to graph: 28/425
# Converting SMILES to graph: 29/425
# Converting SMILES to graph: 30/425
# Converting SMILES to graph: 31/425
# Converting SMILES to graph: 32/425
# Converting SMILES to graph: 33/425
# Converting SMILES to graph: 34/425
# Converting SMILES to graph: 35/425
# Converting SMILES to graph: 36/425
# Converting SMILES to graph: 37/425
# Converting SMILES to graph: 38/425
# Converting SMILES to graph: 39/425
# Converting SMILES to graph: 40/425
# Converting SMILES to graph: 41/425
# Converting SMILES to graph: 42/425
# Converting SMILES to graph: 43/425
# Converting SMILES to graph: 44/425
# Converting SMILES to graph: 45/425
# Converting SMILES to graph: 46/425
# Converting SMILES to graph: 47/425
# Converting SMILES to graph: 48/425
# Converting SMILES to graph: 49/425
# Converting SMILES to graph: 50/425
# Converting SMILES to graph: 51/425
# Converting SMILES to graph: 52/425
# Converting SMILES to graph: 53/425
# Converting SMILES to graph: 54/425
# Converting SMILES to graph: 55/425
# Converting SMILES to graph: 56/425
# Converting SMILES to graph: 57/425
# Converting SMILES to graph: 58/425
# Converting SMILES to graph: 59/425
# Converting SMILES to graph: 60/425
# Converting SMILES to graph: 61/425
# Converting SMILES to graph: 62/425
# Converting SMILES to graph: 63/425
# Converting SMILES to graph: 64/425
# Converting SMILES to graph: 65/425
# Converting SMILES to graph: 66/425
# Converting SMILES to graph: 67/425
# Converting SMILES to graph: 68/425
# Converting SMILES to graph: 69/425
# Converting SMILES to graph: 70/425
# Converting SMILES to graph: 71/425
# Converting SMILES to graph: 72/425
# Converting SMILES to graph: 73/425
# Converting SMILES to graph: 74/425
# Converting SMILES to graph: 75/425
# Converting SMILES to graph: 76/425
# Converting SMILES to graph: 77/425
# Converting SMILES to graph: 78/425
# Converting SMILES to graph: 79/425
# Converting SMILES to graph: 80/425
# Converting SMILES to graph: 81/425
# Converting SMILES to graph: 82/425
# Converting SMILES to graph: 83/425
# Converting SMILES to graph: 84/425
# Converting SMILES to graph: 85/425
# Converting SMILES to graph: 86/425
# Converting SMILES to graph: 87/425
# Converting SMILES to graph: 88/425
# Converting SMILES to graph: 89/425
# Converting SMILES to graph: 90/425
# Converting SMILES to graph: 91/425
# Converting SMILES to graph: 92/425
# Converting SMILES to graph: 93/425
# Converting SMILES to graph: 94/425
# Converting SMILES to graph: 95/425
# Converting SMILES to graph: 96/425
# Converting SMILES to graph: 97/425
# Converting SMILES to graph: 98/425
# Converting SMILES to graph: 99/425
# Converting SMILES to graph: 100/425
# Converting SMILES to graph: 101/425
# Converting SMILES to graph: 102/425
# Converting SMILES to graph: 103/425
# Converting SMILES to graph: 104/425
# Converting SMILES to graph: 105/425
# Converting SMILES to graph: 106/425
# Converting SMILES to graph: 107/425
# Converting SMILES to graph: 108/425
# Converting SMILES to graph: 109/425
# Converting SMILES to graph: 110/425
# Converting SMILES to graph: 111/425
# Converting SMILES to graph: 112/425
# Converting SMILES to graph: 113/425
# Converting SMILES to graph: 114/425
# Converting SMILES to graph: 115/425
# Converting SMILES to graph: 116/425
# Converting SMILES to graph: 117/425
# Converting SMILES to graph: 118/425
# Converting SMILES to graph: 119/425
# Converting SMILES to graph: 120/425
# Converting SMILES to graph: 121/425
# Converting SMILES to graph: 122/425
# Converting SMILES to graph: 123/425
# Converting SMILES to graph: 124/425
# Converting SMILES to graph: 125/425
# Converting SMILES to graph: 126/425
# Converting SMILES to graph: 127/425
# Converting SMILES to graph: 128/425
# Converting SMILES to graph: 129/425
# Converting SMILES to graph: 130/425
# Converting SMILES to graph: 131/425
# Converting SMILES to graph: 132/425
# Converting SMILES to graph: 133/425
# Converting SMILES to graph: 134/425
# Converting SMILES to graph: 135/425
# Converting SMILES to graph: 136/425
# Converting SMILES to graph: 137/425
# Converting SMILES to graph: 138/425
# Converting SMILES to graph: 139/425
# Converting SMILES to graph: 140/425
# Converting SMILES to graph: 141/425
# Converting SMILES to graph: 142/425
# Converting SMILES to graph: 143/425
# Converting SMILES to graph: 144/425
# Converting SMILES to graph: 145/425
# Converting SMILES to graph: 146/425
# Converting SMILES to graph: 147/425
# Converting SMILES to graph: 148/425
# Converting SMILES to graph: 149/425
# Converting SMILES to graph: 150/425
# Converting SMILES to graph: 151/425
# Converting SMILES to graph: 152/425
# Converting SMILES to graph: 153/425
# Converting SMILES to graph: 154/425
# Converting SMILES to graph: 155/425
# Converting SMILES to graph: 156/425
# Converting SMILES to graph: 157/425
# Converting SMILES to graph: 158/425
# Converting SMILES to graph: 159/425
# Converting SMILES to graph: 160/425
# Converting SMILES to graph: 161/425
# Converting SMILES to graph: 162/425
# Converting SMILES to graph: 163/425
# Converting SMILES to graph: 164/425
# Converting SMILES to graph: 165/425
# Converting SMILES to graph: 166/425
# Converting SMILES to graph: 167/425
# Converting SMILES to graph: 168/425
# Converting SMILES to graph: 169/425
# Converting SMILES to graph: 170/425
# Converting SMILES to graph: 171/425
# Converting SMILES to graph: 172/425
# Converting SMILES to graph: 173/425
# Converting SMILES to graph: 174/425
# Converting SMILES to graph: 175/425
# Converting SMILES to graph: 176/425
# Converting SMILES to graph: 177/425
# Converting SMILES to graph: 178/425
# Converting SMILES to graph: 179/425
# Converting SMILES to graph: 180/425
# Converting SMILES to graph: 181/425
# Converting SMILES to graph: 182/425
# Converting SMILES to graph: 183/425
# Converting SMILES to graph: 184/425
# Converting SMILES to graph: 185/425
# Converting SMILES to graph: 186/425
# Converting SMILES to graph: 187/425
# Converting SMILES to graph: 188/425
# Converting SMILES to graph: 189/425
# Converting SMILES to graph: 190/425
# Converting SMILES to graph: 191/425
# Converting SMILES to graph: 192/425
# Converting SMILES to graph: 193/425
# Converting SMILES to graph: 194/425
# Converting SMILES to graph: 195/425
# Converting SMILES to graph: 196/425
# Converting SMILES to graph: 197/425
# Converting SMILES to graph: 198/425
# Converting SMILES to graph: 199/425
# Converting SMILES to graph: 200/425
# Converting SMILES to graph: 201/425
# Converting SMILES to graph: 202/425
# Converting SMILES to graph: 203/425
# Converting SMILES to graph: 204/425
# Converting SMILES to graph: 205/425
# Converting SMILES to graph: 206/425
# Converting SMILES to graph: 207/425
# Converting SMILES to graph: 208/425
# Converting SMILES to graph: 209/425
# Converting SMILES to graph: 210/425
# Converting SMILES to graph: 211/425
# Converting SMILES to graph: 212/425
# Converting SMILES to graph: 213/425
# Converting SMILES to graph: 214/425
# Converting SMILES to graph: 215/425
# Converting SMILES to graph: 216/425
# Converting SMILES to graph: 217/425
# Converting SMILES to graph: 218/425
# Converting SMILES to graph: 219/425
# Converting SMILES to graph: 220/425
# Converting SMILES to graph: 221/425
# Converting SMILES to graph: 222/425
# Converting SMILES to graph: 223/425
# Converting SMILES to graph: 224/425
# Converting SMILES to graph: 225/425
# Converting SMILES to graph: 226/425
# Converting SMILES to graph: 227/425
# Converting SMILES to graph: 228/425
# Converting SMILES to graph: 229/425
# Converting SMILES to graph: 230/425
# Converting SMILES to graph: 231/425
# Converting SMILES to graph: 232/425
# Converting SMILES to graph: 233/425
# Converting SMILES to graph: 234/425
# Converting SMILES to graph: 235/425
# Converting SMILES to graph: 236/425
# Converting SMILES to graph: 237/425
# Converting SMILES to graph: 238/425
# Converting SMILES to graph: 239/425
# Converting SMILES to graph: 240/425
# Converting SMILES to graph: 241/425
# Converting SMILES to graph: 242/425
# Converting SMILES to graph: 243/425
# Converting SMILES to graph: 244/425
# Converting SMILES to graph: 245/425
# Converting SMILES to graph: 246/425
# Converting SMILES to graph: 247/425
# Converting SMILES to graph: 248/425
# Converting SMILES to graph: 249/425
# Converting SMILES to graph: 250/425
# Converting SMILES to graph: 251/425
# Converting SMILES to graph: 252/425
# Converting SMILES to graph: 253/425
# Converting SMILES to graph: 254/425
# Converting SMILES to graph: 255/425
# Converting SMILES to graph: 256/425
# Converting SMILES to graph: 257/425
# Converting SMILES to graph: 258/425
# Converting SMILES to graph: 259/425
# Converting SMILES to graph: 260/425
# Converting SMILES to graph: 261/425
# Converting SMILES to graph: 262/425
# Converting SMILES to graph: 263/425
# Converting SMILES to graph: 264/425
# Converting SMILES to graph: 265/425
# Converting SMILES to graph: 266/425
# Converting SMILES to graph: 267/425
# Converting SMILES to graph: 268/425
# Converting SMILES to graph: 269/425
# Converting SMILES to graph: 270/425
# Converting SMILES to graph: 271/425
# Converting SMILES to graph: 272/425
# Converting SMILES to graph: 273/425
# Converting SMILES to graph: 274/425
# Converting SMILES to graph: 275/425
# Converting SMILES to graph: 276/425
# Converting SMILES to graph: 277/425
# Converting SMILES to graph: 278/425
# Converting SMILES to graph: 279/425
# Converting SMILES to graph: 280/425
# Converting SMILES to graph: 281/425
# Converting SMILES to graph: 282/425
# Converting SMILES to graph: 283/425
# Converting SMILES to graph: 284/425
# Converting SMILES to graph: 285/425
# Converting SMILES to graph: 286/425
# Converting SMILES to graph: 287/425
# Converting SMILES to graph: 288/425
# Converting SMILES to graph: 289/425
# Converting SMILES to graph: 290/425
# Converting SMILES to graph: 291/425
# Converting SMILES to graph: 292/425
# Converting SMILES to graph: 293/425
# Converting SMILES to graph: 294/425
# Converting SMILES to graph: 295/425
# Converting SMILES to graph: 296/425
# Converting SMILES to graph: 297/425
# Converting SMILES to graph: 298/425
# Converting SMILES to graph: 299/425
# Converting SMILES to graph: 300/425
# Converting SMILES to graph: 301/425
# Converting SMILES to graph: 302/425
# Converting SMILES to graph: 303/425
# Converting SMILES to graph: 304/425
# Converting SMILES to graph: 305/425
# Converting SMILES to graph: 306/425
# Converting SMILES to graph: 307/425
# Converting SMILES to graph: 308/425
# Converting SMILES to graph: 309/425
# Converting SMILES to graph: 310/425
# Converting SMILES to graph: 311/425
# Converting SMILES to graph: 312/425
# Converting SMILES to graph: 313/425
# Converting SMILES to graph: 314/425
# Converting SMILES to graph: 315/425
# Converting SMILES to graph: 316/425
# Converting SMILES to graph: 317/425
# Converting SMILES to graph: 318/425
# Converting SMILES to graph: 319/425
# Converting SMILES to graph: 320/425
# Converting SMILES to graph: 321/425
# Converting SMILES to graph: 322/425
# Converting SMILES to graph: 323/425
# Converting SMILES to graph: 324/425
# Converting SMILES to graph: 325/425
# Converting SMILES to graph: 326/425
# Converting SMILES to graph: 327/425
# Converting SMILES to graph: 328/425
# Converting SMILES to graph: 329/425
# Converting SMILES to graph: 330/425
# Converting SMILES to graph: 331/425
# Converting SMILES to graph: 332/425
# Converting SMILES to graph: 333/425
# Converting SMILES to graph: 334/425
# Converting SMILES to graph: 335/425
# Converting SMILES to graph: 336/425
# Converting SMILES to graph: 337/425
# Converting SMILES to graph: 338/425
# Converting SMILES to graph: 339/425
# Converting SMILES to graph: 340/425
# Converting SMILES to graph: 341/425
# Converting SMILES to graph: 342/425
# Converting SMILES to graph: 343/425
# Converting SMILES to graph: 344/425
# Converting SMILES to graph: 345/425
# Converting SMILES to graph: 346/425
# Converting SMILES to graph: 347/425
# Converting SMILES to graph: 348/425
# Converting SMILES to graph: 349/425
# Converting SMILES to graph: 350/425
# Converting SMILES to graph: 351/425
# Converting SMILES to graph: 352/425
# Converting SMILES to graph: 353/425
# Converting SMILES to graph: 354/425
# Converting SMILES to graph: 355/425
# Converting SMILES to graph: 356/425
# Converting SMILES to graph: 357/425
# Converting SMILES to graph: 358/425
# Converting SMILES to graph: 359/425
# Converting SMILES to graph: 360/425
# Converting SMILES to graph: 361/425
# Converting SMILES to graph: 362/425
# Converting SMILES to graph: 363/425
# Converting SMILES to graph: 364/425
# Converting SMILES to graph: 365/425
# Converting SMILES to graph: 366/425
# Converting SMILES to graph: 367/425
# Converting SMILES to graph: 368/425
# Converting SMILES to graph: 369/425
# Converting SMILES to graph: 370/425
# Converting SMILES to graph: 371/425
# Converting SMILES to graph: 372/425
# Converting SMILES to graph: 373/425
# Converting SMILES to graph: 374/425
# Converting SMILES to graph: 375/425
# Converting SMILES to graph: 376/425
# Converting SMILES to graph: 377/425
# Converting SMILES to graph: 378/425
# Converting SMILES to graph: 379/425
# Converting SMILES to graph: 380/425
# Converting SMILES to graph: 381/425
# Converting SMILES to graph: 382/425
# Converting SMILES to graph: 383/425
# Converting SMILES to graph: 384/425
# Converting SMILES to graph: 385/425
# Converting SMILES to graph: 386/425
# Converting SMILES to graph: 387/425
# Converting SMILES to graph: 388/425
# Converting SMILES to graph: 389/425
# Converting SMILES to graph: 390/425
# Converting SMILES to graph: 391/425
# Converting SMILES to graph: 392/425
# Converting SMILES to graph: 393/425
# Converting SMILES to graph: 394/425
# Converting SMILES to graph: 395/425
# Converting SMILES to graph: 396/425
# Converting SMILES to graph: 397/425
# Converting SMILES to graph: 398/425
# Converting SMILES to graph: 399/425
# Converting SMILES to graph: 400/425
# Converting SMILES to graph: 401/425
# Converting SMILES to graph: 402/425
# Converting SMILES to graph: 403/425
# Converting SMILES to graph: 404/425
# Converting SMILES to graph: 405/425
# Converting SMILES to graph: 406/425
# Converting SMILES to graph: 407/425
# Converting SMILES to graph: 408/425
# Converting SMILES to graph: 409/425
# Converting SMILES to graph: 410/425
# Converting SMILES to graph: 411/425
# Converting SMILES to graph: 412/425
# Converting SMILES to graph: 413/425
# Converting SMILES to graph: 414/425
# Converting SMILES to graph: 415/425
# Converting SMILES to graph: 416/425
# Converting SMILES to graph: 417/425
# Converting SMILES to graph: 418/425
# Converting SMILES to graph: 419/425
# Converting SMILES to graph: 420/425
# Converting SMILES to graph: 421/425
# Converting SMILES to graph: 422/425
# Converting SMILES to graph: 423/425
# Converting SMILES to graph: 424/425
# Converting SMILES to graph: 425/425
# Graph construction done. Saving to file.
# /home/waleed/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:62: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# Pre-processed data data_perparation/processed/A375_drug2.pt not found, doing pre-processing...
# Converting SMILES to graph: 1/425
# Converting SMILES to graph: 2/425
# Converting SMILES to graph: 3/425
# Converting SMILES to graph: 4/425
# Converting SMILES to graph: 5/425
# Converting SMILES to graph: 6/425
# Converting SMILES to graph: 7/425
# Converting SMILES to graph: 8/425
# Converting SMILES to graph: 9/425
# Converting SMILES to graph: 10/425
# Converting SMILES to graph: 11/425
# Converting SMILES to graph: 12/425
# Converting SMILES to graph: 13/425
# Converting SMILES to graph: 14/425
# Converting SMILES to graph: 15/425
# Converting SMILES to graph: 16/425
# Converting SMILES to graph: 17/425
# Converting SMILES to graph: 18/425
# Converting SMILES to graph: 19/425
# Converting SMILES to graph: 20/425
# Converting SMILES to graph: 21/425
# Converting SMILES to graph: 22/425
# Converting SMILES to graph: 23/425
# Converting SMILES to graph: 24/425
# Converting SMILES to graph: 25/425
# Converting SMILES to graph: 26/425
# Converting SMILES to graph: 27/425
# Converting SMILES to graph: 28/425
# Converting SMILES to graph: 29/425
# Converting SMILES to graph: 30/425
# Converting SMILES to graph: 31/425
# Converting SMILES to graph: 32/425
# Converting SMILES to graph: 33/425
# Converting SMILES to graph: 34/425
# Converting SMILES to graph: 35/425
# Converting SMILES to graph: 36/425
# Converting SMILES to graph: 37/425
# Converting SMILES to graph: 38/425
# Converting SMILES to graph: 39/425
# Converting SMILES to graph: 40/425
# Converting SMILES to graph: 41/425
# Converting SMILES to graph: 42/425
# Converting SMILES to graph: 43/425
# Converting SMILES to graph: 44/425
# Converting SMILES to graph: 45/425
# Converting SMILES to graph: 46/425
# Converting SMILES to graph: 47/425
# Converting SMILES to graph: 48/425
# Converting SMILES to graph: 49/425
# Converting SMILES to graph: 50/425
# Converting SMILES to graph: 51/425
# Converting SMILES to graph: 52/425
# Converting SMILES to graph: 53/425
# Converting SMILES to graph: 54/425
# Converting SMILES to graph: 55/425
# Converting SMILES to graph: 56/425
# Converting SMILES to graph: 57/425
# Converting SMILES to graph: 58/425
# Converting SMILES to graph: 59/425
# Converting SMILES to graph: 60/425
# Converting SMILES to graph: 61/425
# Converting SMILES to graph: 62/425
# Converting SMILES to graph: 63/425
# Converting SMILES to graph: 64/425
# Converting SMILES to graph: 65/425
# Converting SMILES to graph: 66/425
# Converting SMILES to graph: 67/425
# Converting SMILES to graph: 68/425
# Converting SMILES to graph: 69/425
# Converting SMILES to graph: 70/425
# Converting SMILES to graph: 71/425
# Converting SMILES to graph: 72/425
# Converting SMILES to graph: 73/425
# Converting SMILES to graph: 74/425
# Converting SMILES to graph: 75/425
# Converting SMILES to graph: 76/425
# Converting SMILES to graph: 77/425
# Converting SMILES to graph: 78/425
# Converting SMILES to graph: 79/425
# Converting SMILES to graph: 80/425
# Converting SMILES to graph: 81/425
# Converting SMILES to graph: 82/425
# Converting SMILES to graph: 83/425
# Converting SMILES to graph: 84/425
# Converting SMILES to graph: 85/425
# Converting SMILES to graph: 86/425
# Converting SMILES to graph: 87/425
# Converting SMILES to graph: 88/425
# Converting SMILES to graph: 89/425
# Converting SMILES to graph: 90/425
# Converting SMILES to graph: 91/425
# Converting SMILES to graph: 92/425
# Converting SMILES to graph: 93/425
# Converting SMILES to graph: 94/425
# Converting SMILES to graph: 95/425
# Converting SMILES to graph: 96/425
# Converting SMILES to graph: 97/425
# Converting SMILES to graph: 98/425
# Converting SMILES to graph: 99/425
# Converting SMILES to graph: 100/425
# Converting SMILES to graph: 101/425
# Converting SMILES to graph: 102/425
# Converting SMILES to graph: 103/425
# Converting SMILES to graph: 104/425
# Converting SMILES to graph: 105/425
# Converting SMILES to graph: 106/425
# Converting SMILES to graph: 107/425
# Converting SMILES to graph: 108/425
# Converting SMILES to graph: 109/425
# Converting SMILES to graph: 110/425
# Converting SMILES to graph: 111/425
# Converting SMILES to graph: 112/425
# Converting SMILES to graph: 113/425
# Converting SMILES to graph: 114/425
# Converting SMILES to graph: 115/425
# Converting SMILES to graph: 116/425
# Converting SMILES to graph: 117/425
# Converting SMILES to graph: 118/425
# Converting SMILES to graph: 119/425
# Converting SMILES to graph: 120/425
# Converting SMILES to graph: 121/425
# Converting SMILES to graph: 122/425
# Converting SMILES to graph: 123/425
# Converting SMILES to graph: 124/425
# Converting SMILES to graph: 125/425
# Converting SMILES to graph: 126/425
# Converting SMILES to graph: 127/425
# Converting SMILES to graph: 128/425
# Converting SMILES to graph: 129/425
# Converting SMILES to graph: 130/425
# Converting SMILES to graph: 131/425
# Converting SMILES to graph: 132/425
# Converting SMILES to graph: 133/425
# Converting SMILES to graph: 134/425
# Converting SMILES to graph: 135/425
# Converting SMILES to graph: 136/425
# Converting SMILES to graph: 137/425
# Converting SMILES to graph: 138/425
# Converting SMILES to graph: 139/425
# Converting SMILES to graph: 140/425
# Converting SMILES to graph: 141/425
# Converting SMILES to graph: 142/425
# Converting SMILES to graph: 143/425
# Converting SMILES to graph: 144/425
# Converting SMILES to graph: 145/425
# Converting SMILES to graph: 146/425
# Converting SMILES to graph: 147/425
# Converting SMILES to graph: 148/425
# Converting SMILES to graph: 149/425
# Converting SMILES to graph: 150/425
# Converting SMILES to graph: 151/425
# Converting SMILES to graph: 152/425
# Converting SMILES to graph: 153/425
# Converting SMILES to graph: 154/425
# Converting SMILES to graph: 155/425
# Converting SMILES to graph: 156/425
# Converting SMILES to graph: 157/425
# Converting SMILES to graph: 158/425
# Converting SMILES to graph: 159/425
# Converting SMILES to graph: 160/425
# Converting SMILES to graph: 161/425
# Converting SMILES to graph: 162/425
# Converting SMILES to graph: 163/425
# Converting SMILES to graph: 164/425
# Converting SMILES to graph: 165/425
# Converting SMILES to graph: 166/425
# Converting SMILES to graph: 167/425
# Converting SMILES to graph: 168/425
# Converting SMILES to graph: 169/425
# Converting SMILES to graph: 170/425
# Converting SMILES to graph: 171/425
# Converting SMILES to graph: 172/425
# Converting SMILES to graph: 173/425
# Converting SMILES to graph: 174/425
# Converting SMILES to graph: 175/425
# Converting SMILES to graph: 176/425
# Converting SMILES to graph: 177/425
# Converting SMILES to graph: 178/425
# Converting SMILES to graph: 179/425
# Converting SMILES to graph: 180/425
# Converting SMILES to graph: 181/425
# Converting SMILES to graph: 182/425
# Converting SMILES to graph: 183/425
# Converting SMILES to graph: 184/425
# Converting SMILES to graph: 185/425
# Converting SMILES to graph: 186/425
# Converting SMILES to graph: 187/425
# Converting SMILES to graph: 188/425
# Converting SMILES to graph: 189/425
# Converting SMILES to graph: 190/425
# Converting SMILES to graph: 191/425
# Converting SMILES to graph: 192/425
# Converting SMILES to graph: 193/425
# Converting SMILES to graph: 194/425
# Converting SMILES to graph: 195/425
# Converting SMILES to graph: 196/425
# Converting SMILES to graph: 197/425
# Converting SMILES to graph: 198/425
# Converting SMILES to graph: 199/425
# Converting SMILES to graph: 200/425
# Converting SMILES to graph: 201/425
# Converting SMILES to graph: 202/425
# Converting SMILES to graph: 203/425
# Converting SMILES to graph: 204/425
# Converting SMILES to graph: 205/425
# Converting SMILES to graph: 206/425
# Converting SMILES to graph: 207/425
# Converting SMILES to graph: 208/425
# Converting SMILES to graph: 209/425
# Converting SMILES to graph: 210/425
# Converting SMILES to graph: 211/425
# Converting SMILES to graph: 212/425
# Converting SMILES to graph: 213/425
# Converting SMILES to graph: 214/425
# Converting SMILES to graph: 215/425
# Converting SMILES to graph: 216/425
# Converting SMILES to graph: 217/425
# Converting SMILES to graph: 218/425
# Converting SMILES to graph: 219/425
# Converting SMILES to graph: 220/425
# Converting SMILES to graph: 221/425
# Converting SMILES to graph: 222/425
# Converting SMILES to graph: 223/425
# Converting SMILES to graph: 224/425
# Converting SMILES to graph: 225/425
# Converting SMILES to graph: 226/425
# Converting SMILES to graph: 227/425
# Converting SMILES to graph: 228/425
# Converting SMILES to graph: 229/425
# Converting SMILES to graph: 230/425
# Converting SMILES to graph: 231/425
# Converting SMILES to graph: 232/425
# Converting SMILES to graph: 233/425
# Converting SMILES to graph: 234/425
# Converting SMILES to graph: 235/425
# Converting SMILES to graph: 236/425
# Converting SMILES to graph: 237/425
# Converting SMILES to graph: 238/425
# Converting SMILES to graph: 239/425
# Converting SMILES to graph: 240/425
# Converting SMILES to graph: 241/425
# Converting SMILES to graph: 242/425
# Converting SMILES to graph: 243/425
# Converting SMILES to graph: 244/425
# Converting SMILES to graph: 245/425
# Converting SMILES to graph: 246/425
# Converting SMILES to graph: 247/425
# Converting SMILES to graph: 248/425
# Converting SMILES to graph: 249/425
# Converting SMILES to graph: 250/425
# Converting SMILES to graph: 251/425
# Converting SMILES to graph: 252/425
# Converting SMILES to graph: 253/425
# Converting SMILES to graph: 254/425
# Converting SMILES to graph: 255/425
# Converting SMILES to graph: 256/425
# Converting SMILES to graph: 257/425
# Converting SMILES to graph: 258/425
# Converting SMILES to graph: 259/425
# Converting SMILES to graph: 260/425
# Converting SMILES to graph: 261/425
# Converting SMILES to graph: 262/425
# Converting SMILES to graph: 263/425
# Converting SMILES to graph: 264/425
# Converting SMILES to graph: 265/425
# Converting SMILES to graph: 266/425
# Converting SMILES to graph: 267/425
# Converting SMILES to graph: 268/425
# Converting SMILES to graph: 269/425
# Converting SMILES to graph: 270/425
# Converting SMILES to graph: 271/425
# Converting SMILES to graph: 272/425
# Converting SMILES to graph: 273/425
# Converting SMILES to graph: 274/425
# Converting SMILES to graph: 275/425
# Converting SMILES to graph: 276/425
# Converting SMILES to graph: 277/425
# Converting SMILES to graph: 278/425
# Converting SMILES to graph: 279/425
# Converting SMILES to graph: 280/425
# Converting SMILES to graph: 281/425
# Converting SMILES to graph: 282/425
# Converting SMILES to graph: 283/425
# Converting SMILES to graph: 284/425
# Converting SMILES to graph: 285/425
# Converting SMILES to graph: 286/425
# Converting SMILES to graph: 287/425
# Converting SMILES to graph: 288/425
# Converting SMILES to graph: 289/425
# Converting SMILES to graph: 290/425
# Converting SMILES to graph: 291/425
# Converting SMILES to graph: 292/425
# Converting SMILES to graph: 293/425
# Converting SMILES to graph: 294/425
# Converting SMILES to graph: 295/425
# Converting SMILES to graph: 296/425
# Converting SMILES to graph: 297/425
# Converting SMILES to graph: 298/425
# Converting SMILES to graph: 299/425
# Converting SMILES to graph: 300/425
# Converting SMILES to graph: 301/425
# Converting SMILES to graph: 302/425
# Converting SMILES to graph: 303/425
# Converting SMILES to graph: 304/425
# Converting SMILES to graph: 305/425
# Converting SMILES to graph: 306/425
# Converting SMILES to graph: 307/425
# Converting SMILES to graph: 308/425
# Converting SMILES to graph: 309/425
# Converting SMILES to graph: 310/425
# Converting SMILES to graph: 311/425
# Converting SMILES to graph: 312/425
# Converting SMILES to graph: 313/425
# Converting SMILES to graph: 314/425
# Converting SMILES to graph: 315/425
# Converting SMILES to graph: 316/425
# Converting SMILES to graph: 317/425
# Converting SMILES to graph: 318/425
# Converting SMILES to graph: 319/425
# Converting SMILES to graph: 320/425
# Converting SMILES to graph: 321/425
# Converting SMILES to graph: 322/425
# Converting SMILES to graph: 323/425
# Converting SMILES to graph: 324/425
# Converting SMILES to graph: 325/425
# Converting SMILES to graph: 326/425
# Converting SMILES to graph: 327/425
# Converting SMILES to graph: 328/425
# Converting SMILES to graph: 329/425
# Converting SMILES to graph: 330/425
# Converting SMILES to graph: 331/425
# Converting SMILES to graph: 332/425
# Converting SMILES to graph: 333/425
# Converting SMILES to graph: 334/425
# Converting SMILES to graph: 335/425
# Converting SMILES to graph: 336/425
# Converting SMILES to graph: 337/425
# Converting SMILES to graph: 338/425
# Converting SMILES to graph: 339/425
# Converting SMILES to graph: 340/425
# Converting SMILES to graph: 341/425
# Converting SMILES to graph: 342/425
# Converting SMILES to graph: 343/425
# Converting SMILES to graph: 344/425
# Converting SMILES to graph: 345/425
# Converting SMILES to graph: 346/425
# Converting SMILES to graph: 347/425
# Converting SMILES to graph: 348/425
# Converting SMILES to graph: 349/425
# Converting SMILES to graph: 350/425
# Converting SMILES to graph: 351/425
# Converting SMILES to graph: 352/425
# Converting SMILES to graph: 353/425
# Converting SMILES to graph: 354/425
# Converting SMILES to graph: 355/425
# Converting SMILES to graph: 356/425
# Converting SMILES to graph: 357/425
# Converting SMILES to graph: 358/425
# Converting SMILES to graph: 359/425
# Converting SMILES to graph: 360/425
# Converting SMILES to graph: 361/425
# Converting SMILES to graph: 362/425
# Converting SMILES to graph: 363/425
# Converting SMILES to graph: 364/425
# Converting SMILES to graph: 365/425
# Converting SMILES to graph: 366/425
# Converting SMILES to graph: 367/425
# Converting SMILES to graph: 368/425
# Converting SMILES to graph: 369/425
# Converting SMILES to graph: 370/425
# Converting SMILES to graph: 371/425
# Converting SMILES to graph: 372/425
# Converting SMILES to graph: 373/425
# Converting SMILES to graph: 374/425
# Converting SMILES to graph: 375/425
# Converting SMILES to graph: 376/425
# Converting SMILES to graph: 377/425
# Converting SMILES to graph: 378/425
# Converting SMILES to graph: 379/425
# Converting SMILES to graph: 380/425
# Converting SMILES to graph: 381/425
# Converting SMILES to graph: 382/425
# Converting SMILES to graph: 383/425
# Converting SMILES to graph: 384/425
# Converting SMILES to graph: 385/425
# Converting SMILES to graph: 386/425
# Converting SMILES to graph: 387/425
# Converting SMILES to graph: 388/425
# Converting SMILES to graph: 389/425
# Converting SMILES to graph: 390/425
# Converting SMILES to graph: 391/425
# Converting SMILES to graph: 392/425
# Converting SMILES to graph: 393/425
# Converting SMILES to graph: 394/425
# Converting SMILES to graph: 395/425
# Converting SMILES to graph: 396/425
# Converting SMILES to graph: 397/425
# Converting SMILES to graph: 398/425
# Converting SMILES to graph: 399/425
# Converting SMILES to graph: 400/425
# Converting SMILES to graph: 401/425
# Converting SMILES to graph: 402/425
# Converting SMILES to graph: 403/425
# Converting SMILES to graph: 404/425
# Converting SMILES to graph: 405/425
# Converting SMILES to graph: 406/425
# Converting SMILES to graph: 407/425
# Converting SMILES to graph: 408/425
# Converting SMILES to graph: 409/425
# Converting SMILES to graph: 410/425
# Converting SMILES to graph: 411/425
# Converting SMILES to graph: 412/425
# Converting SMILES to graph: 413/425
# Converting SMILES to graph: 414/425
# Converting SMILES to graph: 415/425
# Converting SMILES to graph: 416/425
# Converting SMILES to graph: 417/425
# Converting SMILES to graph: 418/425
# Converting SMILES to graph: 419/425
# Converting SMILES to graph: 420/425
# Converting SMILES to graph: 421/425
# Converting SMILES to graph: 422/425
# Converting SMILES to graph: 423/425
# Converting SMILES to graph: 424/425
# Converting SMILES to graph: 425/425
# Graph construction done. Saving to file.
# preparing  A375_.pt in pytorch format!
